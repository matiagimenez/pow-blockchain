# %%
from block_orchestrator.schemas import Block

block = Block.model_validate(
    {
        "timestamp": "1763764343",
        "hash": "00006a0f938e321fe2058a02cc42061b",
        "previous_hash": "00000000000000000000000000000000",
        "transactions": [],
        "index": 1,
        "nonce": 53014,
    }
)

block.is_valid
# Out:
# True

# %%
from block_orchestrator.services import BlockService

service = BlockService()

await service.add_block_to_chain(block)
# Out:
# 2025-11-21 19:43:04 | INFO | Adding block to chain {
#     "timestamp": "1763764343",
#     "hash_": "00006a0f938e321fe2058a02cc42061b",
#     "previous_hash": "00000000000000000000000000000000",
#     "index": 1,
#     "nonce": 53014
# }
# 2025-11-21 19:43:04 | ERROR | Failed to add block to chain 00006a0f938e321fe2058a02cc42061b: Invalid input of type: 'list'. Convert to a bytes, string, int or float first.
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       1 from block_orchestrator.services import BlockService
#       3 service = BlockService()
# ----> 5 await service.add_block_to_chain(block)
#
# File d:\repositories\pow-blockchain\block-orchestrator\block_orchestrator\services\block.py:32, in BlockService.add_block_to_chain(self, block)
#      30     async with RedisClient() as redis:
#      31         await redis.zadd("block_hashes", {block.hash_: timestamp})
# ---> 32         await redis.hset(
#      33             block_key, mapping=block.model_dump(by_alias=True, mode="json")
#      34         )
#      35 except Exception as e:
#      36     logger.error(f"Failed to add block to chain {block.hash_}: {e}")
#
# File d:\repositories\pow-blockchain\block-orchestrator\.venv\Lib\site-packages\redis\asyncio\client.py:725, in Redis.execute_command(self, *args, **options)
#     723     await self._single_conn_lock.acquire()
#     724 try:
# --> 725     return await conn.retry.call_with_retry(
#     726         lambda: self._send_command_parse_response(
#     727             conn, command_name, *args, **options
#     728         ),
#     729         lambda _: self._close_connection(conn),
#     730     )
#     731 finally:
#     732     if self.single_connection_client:
#
# File d:\repositories\pow-blockchain\block-orchestrator\.venv\Lib\site-packages\redis\asyncio\retry.py:50, in Retry.call_with_retry(self, do, fail)
#      48 while True:
#      49     try:
# ---> 50         return await do()
#      51     except self._supported_errors as error:
#      52         failures += 1
#
# File d:\repositories\pow-blockchain\block-orchestrator\.venv\Lib\site-packages\redis\asyncio\client.py:699, in Redis._send_command_parse_response(self, conn, command_name, *args, **options)
#     695 async def _send_command_parse_response(self, conn, command_name, *args, **options):
#     696     """
#     697     Send a command and parse the response
#     698     """
# --> 699     await conn.send_command(*args)
#     700     return await self.parse_response(conn, command_name, **options)
#
# File d:\repositories\pow-blockchain\block-orchestrator\.venv\Lib\site-packages\redis\asyncio\connection.py:568, in AbstractConnection.send_command(self, *args, **kwargs)
#     565 async def send_command(self, *args: Any, **kwargs: Any) -> None:
#     566     """Pack and send a command to the Redis server"""
#     567     await self.send_packed_command(
# --> 568         self.pack_command(*args), check_health=kwargs.get("check_health", True)
#     569     )
#
# File d:\repositories\pow-blockchain\block-orchestrator\.venv\Lib\site-packages\redis\asyncio\connection.py:655, in AbstractConnection.pack_command(self, *args)
#     652 buff = SYM_EMPTY.join((SYM_STAR, str(len(args)).encode(), SYM_CRLF))
#     654 buffer_cutoff = self._buffer_cutoff
# --> 655 for arg in map(self.encoder.encode, args):
#     656     # to avoid large string mallocs, chunk the command into the
#     657     # output list if we're sending large values or memoryviews
#     658     arg_length = len(arg)
#     659     if (
#     660         len(buff) > buffer_cutoff
#     661         or arg_length > buffer_cutoff
#     662         or isinstance(arg, memoryview)
#     663     ):
#
# File d:\repositories\pow-blockchain\block-orchestrator\.venv\Lib\site-packages\redis\_parsers\encoders.py:29, in Encoder.encode(self, value)
#      26 elif not isinstance(value, str):
#      27     # a value we don't know how to deal with. throw an error
#      28     typename = type(value).__name__
# ---> 29     raise DataError(
#      30         f"Invalid input of type: '{typename}'. "
#      31         f"Convert to a bytes, string, int or float first."
#      32     )
#      33 if isinstance(value, str):
#      34     value = value.encode(self.encoding, self.encoding_errors)
#
# DataError: Invalid input of type: 'list'. Convert to a bytes, string, int or float first.
